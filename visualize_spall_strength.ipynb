# %%
#@title Visualize the Dataset for Spall Strengths of Metals and Alloys

# Import packages
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import io
from matplotlib.ticker import AutoMinorLocator
from scipy import stats

# Import models
if os.path.exists("/usr/local/spall_strength_prediction"):
  pass
else:
  # %cd /usr/local
  # !git clone -q https://github.com/Ramprasad-Group/spall_strength_prediction.git
# Out:
# /usr/local

# %%
# Plot the dataset
df = pd.read_csv('/usr/local/spall_strength_prediction/dataset/metals&alloys.csv')
df1 = df.sort_values('spall_median')

fig = plt.figure(figsize=(15, 5))
ax = plt.gca()

plt.errorbar(df1['label'], df1['spall_median'], fmt='none', ecolor = 'gray', elinewidth=1, zorder=0)



sns.scatterplot(data=df1, x=df1['label'], y=df1['spall_median'],
                s=50, zorder=1, legend="full")

handles, labels = ax.get_legend_handles_labels()

plt.title('Spall Strength of Metals and Alloys', fontsize=20)
plt.xlabel('Metals and Alloys', fontsize=18)
ax.set_xticks(np.arange(-0.5, 71, 1), minor=True)
ax.tick_params(axis="x",direction="in", pad=2)
plt.xticks(rotation=90)


plt.ylim(0,8)
plt.ylabel('Spall Strength (GPa)', fontsize=18)

plt.tick_params(bottom = False)
plt.tick_params(axis='y', labelsize=15)


plt.margins(x=0.008)
plt.show()

# %%
# Plot the features

labels = 35
mini = 0
maxi = 8
anns = 22
val = 28
size = 100


fig = plt.figure(figsize=(36, 27), constrained_layout=False)
gs = fig.add_gridspec(3, 3,  width_ratios=(1, 1, 1),height_ratios=(1, 1,1),)


#######################################################################################################
p_1 = fig.add_subplot(gs[0, 0])

plt.ylabel('Spall Strength (GPa)', fontsize=labels)
plt.ylim(mini, maxi)
plt.yticks(np.arange(0, 9, 1.0))

plt.text(150, 7, 'r=0.535', color='black', fontsize=anns,
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.xlabel('Ultimate Tensile Strength (MPa)', fontsize=labels)
plt.xlim(0, 2000)
plt.tick_params(labelsize=val)

sns.scatterplot(data=df, x=df['UTS'], y=df['spall_median'],
                s=size)


####################################################################################################
p_2 = fig.add_subplot(gs[0, 1])

plt.ylabel('Spall Strength (GPa)', fontsize=labels)
plt.ylim(mini, maxi)
plt.yticks(np.arange(0, 9, 1.0))

plt.text(100, 7, 'r=0.536', color='black', fontsize=anns,
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.xlabel('Tensile Yield Strength (MPa)', fontsize=labels)
plt.xlim(0, 1400)
plt.tick_params(labelsize=val)


sns.scatterplot(data=df, x=df['yield_strength'], y=df['spall_median'],
                s=size, zorder=1)
plt.legend([],[], frameon=False)

########################################################################################################

p_4 = fig.add_subplot(gs[-2, 0])

plt.ylabel('Spall Strength (GPa)', fontsize=labels)
plt.ylim(mini, maxi)
plt.yticks(np.arange(0, 9, 1.0))

plt.text(25, 7, 'r=0.392', color='black', fontsize=anns,
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.xlabel('Fracture Toughness (MPa√m)', fontsize=labels)
plt.xlim(0, 350)
plt.tick_params(labelsize=val)


sns.scatterplot(data=df, x=df['fracture_toughness'], y=df['spall_median'],
                s=size, zorder=1)
plt.legend([],[], frameon=False)

########################################################################################################

p_5 = fig.add_subplot(gs[-2, 1])


plt.ylabel('Spall Strength (GPa)', fontsize=labels)
plt.ylim(mini, maxi)
plt.yticks(np.arange(0, 9, 1.0))

plt.text(130, 7, 'r=0.309', color='black', fontsize=anns,
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.xlabel('Vickers Hardness', fontsize=labels)
plt.xlim(0, 1750)
plt.tick_params(labelsize=val)


sns.scatterplot(data=df, x=df['hardness'], y=df['spall_median'],
                s=size, zorder=1)
plt.legend([],[], frameon=False)

########################################################################################################

p_6 = fig.add_subplot(gs[-2, 2])


plt.ylabel('Spall Strength (GPa)', fontsize=labels)
plt.ylim(mini, maxi)
plt.yticks(np.arange(0, 9, 1.0))

plt.text(1.5, 7, 'r=0.309', color='black', fontsize=anns,
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.xlabel('Density (g/cc)', fontsize=labels)
plt.xlim(0, 20)
plt.tick_params(labelsize=val)

sns.scatterplot(data=df, x=df['density'], y=df['spall_median'],
                s=size, zorder=1)
plt.legend([],[], frameon=False)

########################################################################################################

p_7 = fig.add_subplot(gs[-1, 0])

plt.ylabel('Spall Strength (GPa)', fontsize=labels)
plt.ylim(mini, maxi)
plt.yticks(np.arange(0, 9, 1.0))

plt.text(40, 7, 'r=0.377', color='black', fontsize=anns,
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.xlabel('Bulk Modulus (GPa)', fontsize=labels)
plt.xlim(0, 500)
plt.tick_params(labelsize=val)


sns.scatterplot(data=df, x=df['bulk_modulus'], y=df['spall_median'],
                s=size, zorder=1)
plt.legend([],[], frameon=False)

########################################################################################################
p_9 = fig.add_subplot(gs[-1, 1])

plt.ylabel('Spall Strength (GPa)', fontsize=labels)
plt.ylim(mini, maxi)
plt.yticks(np.arange(0, 9, 1.0))

plt.text(45, 7, 'r=0.248', color='black', fontsize=anns,
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.xlabel('Youngs Modulus (GPa)', fontsize=labels)
plt.xlim(0, 550)
plt.tick_params(labelsize=val)

sns.scatterplot(data=df, x=df['youngs_modulus'], y=df['spall_median'],
                s=size, zorder=1)
plt.legend([],[], frameon=False)
########################################################################################################

plt.show()
